# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
## Importing the data
columns=['Sex','Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight','Rings']
df=pd.read_csv('abalone.data',names=columns)

# %%
## Checking first few rows
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell Weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# Checking the information
## We find no null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole Weight    4177 non-null   float64
#  5   Shucked Weight  4177 non-null   float64
#  6   Viscera Weight  4177 non-null   float64
#  7   Shell Weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
# Make a copy of the data
df_copy=df.copy()

# %%
# Splitting into features and labels
X=df_copy.drop('Rings',axis=1)
y=df_copy['Rings']

# %%
## Checking y series

# %%
print(y[:5])
# Out:
# 0    15
# 1     7
# 2     9
# 3    10
# 4     7
# Name: Rings, dtype: int64

# %%
#Checking the shape
print(X.shape)
print(y.shape)
# Out:
# (4177, 8)
# (4177,)

# %%
X_transformed=pd.get_dummies(X,prefix='Sex',drop_first=True)

# %%
X_transformed
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Sex_I  Sex_M
# 0           0.1500      0      1
# 1           0.0700      0      1
# 2           0.2100      0      0
# 3           0.1550      0      1
# 4           0.0550      1      0
# ...            ...    ...    ...
# 4172        0.2490      0      0
# 4173        0.2605      0      1
# 4174        0.3080      0      1
# 4175        0.2960      0      0
# 4176        0.4950      0      1
#
# [4177 rows x 9 columns]

# %%
X_transformed.columns=['Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight','Is_Infant','Is_Male']

# %%
X_transformed
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Is_Infant  Is_Male
# 0           0.1500          0        1
# 1           0.0700          0        1
# 2           0.2100          0        0
# 3           0.1550          0        1
# 4           0.0550          1        0
# ...            ...        ...      ...
# 4172        0.2490          0        0
# 4173        0.2605          0        1
# 4174        0.3080          0        1
# 4175        0.2960          0        0
# 4176        0.4950          0        1
#
# [4177 rows x 9 columns]

# %%
#Lets Scale the data on common scale
scaler=StandardScaler()
numeric_cols=list(X_transformed.iloc[:,0:7].columns)
numeric_cols
transformer=ColumnTransformer([('scaler',StandardScaler(),numeric_cols)],remainder='passthrough')
scaled_transformed_X=transformer.fit_transform(X_transformed)
scaled_transformed_X_df=pd.DataFrame(scaled_transformed_X,columns=X_transformed.columns)

# %%
scaled_transformed_X_df.head()
# Out:
#      Length  Diameter    Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.107991     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968       -1.287337
#
#    Shell Weight  Is_Infant  Is_Male
# 0     -0.638217        0.0      1.0
# 1     -1.212987        0.0      1.0
# 2     -0.207139        0.0      0.0
# 3     -0.602294        0.0      1.0
# 4     -1.320757        1.0      0.0

# %%
# Splitting into training,validation and test sets
X_train,X_test,y_train,y_test=train_test_split(scaled_transformed_X_df,y,test_size=0.2,random_state=42)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.2,random_state=42)

# %%
print(len(X_train),len(X_test),len(X_val),len(y_train),len(y_test),len(y_val))
# Out:
# 2672 836 669 2672 836 669

# %%
print(len(X_train)/len(X_transformed)*100)
print(len(X_test)/len(X_transformed)*100)
print(len(X_val)/len(X_transformed)*100)
# Out:
# 63.96935599712712
# 20.01436437634666
# 16.016279626526213

# %%
models={'LR':LinearRegression(),'GBR':GradientBoostingRegressor(),'RF':RandomForestRegressor(),'CART':DecisionTreeRegressor(),'SVR':SVR()}

# %%
for names,model in models.items():
    clf=model.fit(X_train,y_train)
    score=cross_val_score(clf,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
    print("**********Results**************")
    print("Model Name",names)
    print("Model Score",score)
    print("Model Mean",score.mean())
    print("Model Std",score.std())
# Out:
# **********Results**************
# Model Name LR
# Model Score [-4.993395   -5.4711318  -4.75267429 -4.09861414 -4.76247795]
# Model Mean -4.815658635129559
# Model Std 0.44321175654123124
# **********Results**************
# Model Name GBR
# Model Score [-4.41198191 -5.73954151 -4.79023555 -4.04408068 -4.49943049]
# Model Mean -4.697054027846203
# Model Std 0.5730895765096196
# **********Results**************
# Model Name RF
# Model Score [-4.544      -5.66793121 -4.79384326 -4.24594719 -4.59811461]
# Model Mean -4.769967254226609
# Model Std 0.4820997609256954
# **********Results**************
# Model Name CART
# Model Score [ -7.72336449 -10.96448598  -9.37453184  -8.85018727  -8.93820225]
# Model Mean -9.170154363120867
# Model Std 1.0498359665294337
# **********Results**************
# Model Name SVR
# Model Score [-4.24595501 -5.66962676 -4.92697686 -3.94525147 -4.77320201]
# Model Mean -4.712202422779621
# Model Std 0.5953336518990079

# %%
#Wow Random Forest Regressor has performed quite well in terms of Standard Deviation
#So we will select Random Forest has our baseline model

# %%
#Time to Tune our hyperparameters using GridCVDSearch
param_grid=[{'n_estimators':[1,5,10,20,50],'max_features':[5,10,20],'max_depth':[10,50,None],'bootstrap':[True,False]}]
grid=GridSearchCV(RandomForestRegressor(),param_grid=param_grid,cv=10,scoring='neg_mean_squared_error')

# %%
grid.fit(X_val,y_val)
# Out:
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
# ...
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "C:\Users\manis\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [True, False],
#                           'max_depth': [10, 50, None],
#                           'max_features': [5, 10, 20],
#                           'n_estimators': [1, 5, 10, 20, 50]}],
#              scoring='neg_mean_squared_error')

# %%
cvres=grid.cv_results_
for mean_score,params in zip(cvres['mean_test_score'],cvres['params']):
    print(np.sqrt(-mean_score),params)
# Out:
# 2.863561453763744 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 1}
# 2.329583324768541 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 5}
# 2.230773905228679 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 10}
# 2.175026451613495 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 20}
# 2.1359892523988426 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 50}
# 2.9149019019763998 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 1}
# 2.2482680403737225 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 5}
# 2.2641085879158416 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 10}
# 2.2049573197681394 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 20}
# 2.164750778719465 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 50}
# 2.931337722141259 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 1}
# 2.2860121720666156 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 5}
# 2.309583890579753 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 10}
# 2.164897426758447 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 20}
# 2.1515716868499766 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 50}
# 2.9298616665221884 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 1}
# 2.3014413949351864 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 5}
# 2.261879002336075 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 10}
# 2.2235124705096254 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 20}
# 2.233320402212134 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 50}
# 2.9292077089034834 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 1}
# 2.402381413117653 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 5}
# 2.2921710106594673 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 10}
# 2.2769669952421316 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 20}
# 2.251895813199448 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 50}
# 2.770372913291173 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 1}
# 2.374990680550165 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 5}
# 2.281355715071277 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 10}
# 2.220693556833196 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 20}
# 2.255581913683283 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 50}

# %%
grid_best_estimator=grid.best_estimator_

# %%
#Evaluating the metric
y_preds=grid_best_estimator.predict(X_test)

# %%
y_preds
# Out:
# array([10.19741904,  9.81061034, 15.15412225, 11.76119431, 12.04714386,
#        12.19488478,  9.0704955 ,  8.92582683,  7.26200425,  9.98528501,
#        10.87775537,  7.78166667, 12.69645249,  7.09813606,  7.94755696,
#        12.46230707, 14.02384367,  9.99319222, 11.67486529,  7.64340628,
#        14.13835924, 10.57354543, 11.71922619, 10.22356795,  8.98143436,
#         7.61881813,  9.46790362,  7.37183052,  9.83567214, 10.42461108,
#        10.8699642 , 10.38142698,  6.65798715, 10.09171762,  9.22471861,
#         9.67126472,  5.35690867,  4.16      ,  8.30952381,  6.70663977,
#        11.36762779, 13.04827392, 10.1993975 ,  9.16443467, 11.32644931,
#        10.81694083,  9.65009313,  9.55381334, 12.66330758,  5.26      ,
#         6.18962814, 15.89333333,  9.46094624,  4.36      ,  6.25669818,
#        10.90338761, 10.02301558, 12.78195042,  9.85682203,  8.09333333,
#        11.02483834, 12.3064446 ,  9.48598656,  7.2229981 ,  7.47857753,
#        11.40345674,  4.48      ,  6.51603363,  9.23857962, 11.72179219,
#        10.9089094 , 10.95680055,  9.1747211 ,  7.66492777,  9.29154743,
#        10.56549771, 13.55394962, 11.35870561, 10.09280089,  9.19771899,
#        12.69882351, 10.9969924 , 10.18582228,  8.14290726,  6.67470394,
#        10.79185047,  9.24423454,  9.18878571, 10.82676012, 13.88249757,
#        10.51432896, 11.58377404, 10.15700141, 10.41645742, 11.99680871,
#        10.4458902 ,  7.08915569, 10.80896205, 10.54408896,  6.88200781,
#        15.68209798, 11.10536599, 10.56377892, 10.65667077,  9.40315984,
#         9.94147619, 11.36741983,  8.50530769, 10.53236392, 10.1280068 ,
#        10.26930788,  9.22651003, 11.94028605,  9.51080198,  9.4975971 ,
#         5.12      ,  9.58749767, 11.30808378, 11.50761121, 10.65348471,
#         9.95915486,  9.99438595,  9.27090416, 11.12254484, 11.00668864,
#        12.19005566,  9.66857011, 10.15299379, 10.78919405, 13.44934412,
#         9.75300133,  7.56744401, 10.28886102,  4.48      ,  5.70916667,
#         7.69345663,  9.55868536, 10.5010632 ,  6.65083333, 12.11734212,
#         8.33384148,  8.31409091,  9.03840609, 11.3852749 , 11.56932832,
#        11.34310394, 10.79506209, 12.82849206,  9.43086942, 11.85203279,
#         8.67946537, 10.82129171,  9.16075179, 10.71661169,  9.8260577 ,
#        10.18518023, 14.87266667,  5.96854545,  9.69765608,  6.13746639,
#        10.87029202,  6.02135983, 10.55341354, 12.78981943,  7.36236139,
#        13.23074891, 11.92645825, 10.35781153, 10.59962146,  9.3709305 ,
#        11.71094442, 13.64251011, 11.5898859 , 10.24079069,  4.26      ,
#        11.55174687,  6.88867448, 11.36963012,  9.5997069 ,  8.11333333,
#         4.06      ,  9.85063411, 14.63686395, 11.77367652, 10.9024821 ,
#        10.48222181, 10.12286947, 12.08664174,  6.09311688, 11.45829332,
#        10.42574244, 10.6200796 , 10.35368036,  7.8009447 ,  6.97509948,
#         9.75293331, 10.27100752, 12.12212231,  9.14762919,  7.69133333,
#         6.33732303,  4.1       ,  6.41594929,  7.79764103,  9.87366484,
#        11.74510848, 10.72582693,  9.5981573 , 10.23283037,  8.73214494,
#         7.37094869])

# %%
errors=abs(y_preds-y_test)

# %%
mape = np.mean(100 * (errors / y_test))

# %%
accuracy=100-mape

# %%
print('The best model has an accuracy of',round(accuracy,2),'%')
# Out:
# The best model has an accuracy of 84.69 %

# %%
#RMSE
grid_mse=mean_squared_error(y_test,y_preds)
rmse=np.sqrt(grid_mse)
print('The best model has a RMSE of',round(rmse,2))
# Out:
# The best model has a RMSE of 2.32

# %%
y_test_df=pd.Series(y_test)

# %%
y_test_df.reset_index(drop=True,inplace=True)

# %%
y_test=pd.Series(y_test_df)

# %%
y_test
# Out:
# 0       9
# 1       8
# 2      16
# 3       9
# 4      14
#        ..
# 831    11
# 832     8
# 833    10
# 834     8
# 835     7
# Name: Rings, Length: 836, dtype: int64

# %%
y_pred_series=pd.Series(y_preds)

# %%
predicted_values=pd.DataFrame(y_pred_series,columns=['Predicted Values'])

# %%
predicted_values
# Out:
#      Predicted Values
# 0           10.197419
# 1            9.810610
# 2           15.154122
# 3           11.761194
# 4           12.047144
# ..                ...
# 831         10.725827
# 832          9.598157
# 833         10.232830
# 834          8.732145
# 835          7.370949
#
# [836 rows x 1 columns]

# %%
actual_values=pd.DataFrame(y_test)

# %%
actual_values
# Out:
#      Rings
# 0        9
# 1        8
# 2       16
# 3        9
# 4       14
# ..     ...
# 831     11
# 832      8
# 833     10
# 834      8
# 835      7
#
# [836 rows x 1 columns]

# %%
actual_values
# Out:
#      Rings
# 0        9
# 1        8
# 2       16
# 3        9
# 4       14
# ..     ...
# 831     11
# 832      8
# 833     10
# 834      8
# 835      7
#
# [836 rows x 1 columns]

# %%
actual_predicted_values=pd.concat([actual_values,predicted_values],axis=1)

# %%
actual_predicted_values
# Out:
#      Rings  Predicted Values
# 0        9         10.197419
# 1        8          9.810610
# 2       16         15.154122
# 3        9         11.761194
# 4       14         12.047144
# ..     ...               ...
# 831     11         10.725827
# 832      8          9.598157
# 833     10         10.232830
# 834      8          8.732145
# 835      7          7.370949
#
# [836 rows x 2 columns]

# %%
print(type(actual_predicted_values))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
actual_predicted_values.columns=['Actual Values','Predicted Values']

# %%
actual_predicted_values
# Out:
#      Actual Values  Predicted Values
# 0                9         10.197419
# 1                8          9.810610
# 2               16         15.154122
# 3                9         11.761194
# 4               14         12.047144
# ..             ...               ...
# 831             11         10.725827
# 832              8          9.598157
# 833             10         10.232830
# 834              8          8.732145
# 835              7          7.370949
#
# [836 rows x 2 columns]
