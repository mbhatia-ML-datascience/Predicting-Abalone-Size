# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
## Importing the data
columns=['Sex','Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight','Rings']
df=pd.read_csv('abalone.data',names=columns)

# %%
## Checking first few rows
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell Weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# Checking the information
## We find no null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole Weight    4177 non-null   float64
#  5   Shucked Weight  4177 non-null   float64
#  6   Viscera Weight  4177 non-null   float64
#  7   Shell Weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
# Make a copy of the data
df_copy=df.copy()

# %%
# Splitting into features and labels
X=df_copy.drop('Rings',axis=1)
y=df_copy['Rings']

# %%
## Checking y series

# %%
print(y[:5])
# Out:
# 0    15
# 1     7
# 2     9
# 3    10
# 4     7
# Name: Rings, dtype: int64

# %%
#Checking the shape
print(X.shape)
print(y.shape)
# Out:
# (4177, 8)
# (4177,)

# %%
X_transformed=pd.get_dummies(X,prefix='Sex',drop_first=True)

# %%
X_transformed
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Sex_I  Sex_M
# 0           0.1500      0      1
# 1           0.0700      0      1
# 2           0.2100      0      0
# 3           0.1550      0      1
# 4           0.0550      1      0
# ...            ...    ...    ...
# 4172        0.2490      0      0
# 4173        0.2605      0      1
# 4174        0.3080      0      1
# 4175        0.2960      0      0
# 4176        0.4950      0      1
#
# [4177 rows x 9 columns]

# %%
X_transformed.columns=['Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight','Is_Infant','Is_Male']

# %%
X_transformed
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Is_Infant  Is_Male
# 0           0.1500          0        1
# 1           0.0700          0        1
# 2           0.2100          0        0
# 3           0.1550          0        1
# 4           0.0550          1        0
# ...            ...        ...      ...
# 4172        0.2490          0        0
# 4173        0.2605          0        1
# 4174        0.3080          0        1
# 4175        0.2960          0        0
# 4176        0.4950          0        1
#
# [4177 rows x 9 columns]

# %%
#Lets Scale the data on common scale
scaler=StandardScaler()
numeric_cols=list(X_transformed.iloc[:,0:7].columns)
numeric_cols
transformer=ColumnTransformer([('scaler',StandardScaler(),numeric_cols)],remainder='passthrough')
scaled_transformed_X=transformer.fit_transform(X_transformed)
scaled_transformed_X_df=pd.DataFrame(scaled_transformed_X,columns=X_transformed.columns)

# %%
scaled_transformed_X_df.head()
# Out:
#      Length  Diameter    Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.107991     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968       -1.287337
#
#    Shell Weight  Is_Infant  Is_Male
# 0     -0.638217        0.0      1.0
# 1     -1.212987        0.0      1.0
# 2     -0.207139        0.0      0.0
# 3     -0.602294        0.0      1.0
# 4     -1.320757        1.0      0.0

# %%
# Splitting into training,validation and test sets
X_train,X_test,y_train,y_test=train_test_split(scaled_transformed_X_df,y,test_size=0.2,random_state=42)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.2,random_state=42)

# %%
print(len(X_train),len(X_test),len(X_val),len(y_train),len(y_test),len(y_val))
# Out:
# 2672 836 669 2672 836 669

# %%
print(len(X_train)/len(X_transformed)*100)
print(len(X_test)/len(X_transformed)*100)
print(len(X_val)/len(X_transformed)*100)
# Out:
# 63.96935599712712
# 20.01436437634666
# 16.016279626526213

# %%
models={'LR':LinearRegression(),'GBR':GradientBoostingRegressor(),'RF':RandomForestRegressor(),'CART':DecisionTreeRegressor(),'SVR':SVR()}

# %%
for names,model in models.items():
    clf=model.fit(X_train,y_train)
    score=cross_val_score(clf,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
    print("**********Results**************")
    print("Model Name",names)
    print("Model Score",score)
    print("Model Mean",score.mean())
    print("Model Std",score.std())
# Out:
# **********Results**************
# Model Name LR
# Model Score [-4.993395   -5.4711318  -4.75267429 -4.09861414 -4.76247795]
# Model Mean -4.815658635129559
# Model Std 0.44321175654123124
# **********Results**************
# Model Name GBR
# Model Score [-4.39114303 -5.73654985 -4.7986507  -4.06343386 -4.51539378]
# Model Mean -4.701034243479206
# Model Std 0.5690080387367444
# **********Results**************
# Model Name RF
# Model Score [-4.53382075 -5.61935402 -4.93205955 -4.26473109 -4.65442697]
# Model Mean -4.800878473870279
# Model Std 0.46202436882022085
# **********Results**************
# Model Name CART
# Model Score [-8.54392523 -9.82616822 -9.39138577 -8.82771536 -9.47003745]
# Model Mean -9.211846406944591
# Model Std 0.46259348285941954
# **********Results**************
# Model Name SVR
# Model Score [-4.24595501 -5.66962676 -4.92697686 -3.94525147 -4.77320201]
# Model Mean -4.712202422779621
# Model Std 0.5953336518990079

# %%
#Wow Random Forest Regressor has performed quite well in terms of Standard Deviation
#So we will select Random Forest has our baseline model

# %%
#Time to Tune our hyperparameters using GridCVDSearch
param_grid=[{'n_estimators':[1,5,10,20,50],'max_features':[5,10,20],'max_depth':[10,50,None],'bootstrap':[True,False]}]
grid=GridSearchCV(RandomForestRegressor(),param_grid=param_grid,cv=10,scoring='neg_mean_squared_error')

# %%
grid.fit(X_val,y_val)
# Out:
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
# ...
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\mlprojects\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\mlprojects\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\mlprojects\lib\site-packages\sklearn\ensemble\_forest.py", line 170, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 1242, in fit
#     super().fit(
#   File "c:\mlprojects\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [True, False],
#                           'max_depth': [10, 50, None],
#                           'max_features': [5, 10, 20],
#                           'n_estimators': [1, 5, 10, 20, 50]}],
#              scoring='neg_mean_squared_error')

# %%
cvres=grid.cv_results_
for mean_score,params in zip(cvres['mean_test_score'],cvres['params']):
    print(np.sqrt(-mean_score),params)
# Out:
# 2.862209070703102 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 1}
# 2.3388805150483543 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 5}
# 2.2080220157521757 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 10}
# 2.132679664762312 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 20}
# 2.1274684610784815 {'bootstrap': True, 'max_depth': 10, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 10, 'max_features': 20, 'n_estimators': 50}
# 3.085367634801646 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 1}
# 2.337494899705893 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 5}
# 2.2817333544608887 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 10}
# 2.2022361918481095 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 20}
# 2.138227862008359 {'bootstrap': True, 'max_depth': 50, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': 50, 'max_features': 20, 'n_estimators': 50}
# 2.812391009999371 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 1}
# 2.3024815040377637 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 5}
# 2.2018289856285085 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 10}
# 2.177695281491906 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 20}
# 2.134063997443182 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': True, 'max_depth': None, 'max_features': 20, 'n_estimators': 50}
# 2.773729588923409 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 1}
# 2.361621333885067 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 5}
# 2.304920402788061 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 10}
# 2.237713277514198 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 20}
# 2.1919523892965627 {'bootstrap': False, 'max_depth': 10, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 10, 'max_features': 20, 'n_estimators': 50}
# 3.047116067276342 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 1}
# 2.35446495010361 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 5}
# 2.312665655318145 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 10}
# 2.2046423717546677 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 20}
# 2.2603177652310493 {'bootstrap': False, 'max_depth': 50, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': 50, 'max_features': 20, 'n_estimators': 50}
# 2.970185788510927 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 1}
# 2.4280791834351714 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 5}
# 2.395254193271445 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 10}
# 2.2392925155390606 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 20}
# 2.229728830107341 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'n_estimators': 50}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 1}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 5}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 10}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 20}
# nan {'bootstrap': False, 'max_depth': None, 'max_features': 20, 'n_estimators': 50}

# %%
grid_best_estimator=grid.best_estimator_

# %%
#Evaluating the metric
y_preds=grid_best_estimator.predict(X_test)

# %%
y_preds
# Out:
# array([11.06447846,  9.88599686, 14.90445177, 11.89996827, 11.54657241,
#        11.55273789,  7.56264554,  6.12      , 12.11779346, 12.10488202,
#        11.13454707,  5.61333333,  7.03847619, 10.09824237, 14.7045696 ,
#        10.33217294,  6.44      , 11.60557313, 16.07536415, 11.37947799,
#         8.1941584 , 11.74670547, 11.29649882,  4.04      , 11.37837175,
#         6.97298229,  8.86995289, 10.71709685,  8.43726823,  9.62666461,
#        14.04536354,  8.31611905, 11.01888769, 11.38852296,  9.68588139,
#         9.94417417, 10.86718386,  5.45045455,  9.16528735, 12.07187825,
#         9.15214769, 11.78421996, 10.69297914,  7.06383233,  7.16154693,
#         9.14925578, 10.19040972, 10.62346367, 10.82529416, 15.67746309,
#         6.96875211, 13.26835327, 10.97506981, 13.3969188 ,  9.68847619,
#        11.53663956, 11.85891429,  9.38106836, 10.8206711 , 10.66723149,
#        10.17816767,  6.96524738,  7.69776543,  9.44433692,  4.14      ,
#        11.02805577,  9.70365711, 10.13945241,  6.02333333, 11.40726209,
#         9.14518242, 11.59983107, 10.20984836,  9.50843334,  9.17828671,
#        10.44887252, 11.62055426,  7.83526984, 10.17246402, 10.95129041,
#        12.95584631, 13.580529  ,  8.45928313,  6.56932675,  6.33999341,
#        10.58370089,  7.4294364 ,  8.74323633,  9.34307974, 11.18425541,
#         4.44      , 10.26675449, 12.48319072,  9.24428696,  6.48428029,
#        11.18220792, 11.59080519,  6.14571212, 12.42343486, 10.28037196,
#        13.19403463,  5.61581197, 10.75891552,  9.7736304 , 11.59767543,
#         5.77200894, 10.28716786, 11.73491491, 15.51964735, 11.79384482,
#         9.03986137, 11.26044354,  7.34180148, 11.21596956,  8.04734326,
#        11.00257629, 10.67064833, 10.01339489, 11.05087403, 10.33503229,
#        11.2492482 , 10.1786561 , 10.84200758,  7.95191172,  8.13459081,
#         9.30259733,  8.62536827, 10.67957456,  7.96203278,  9.83835209,
#        10.26593365,  4.22      ,  9.59684453, 12.4876504 , 10.8403176 ,
#        15.7242381 , 11.93400551, 12.40650038, 11.33090111, 13.03656694,
#        11.35528938, 13.37905101,  7.92045813,  6.43262978,  9.71190671,
#         4.2       ,  6.53454545, 14.107186  , 13.30055051,  9.77820104,
#        11.71125188, 13.28768071, 11.39879684, 10.4378375 ,  4.26      ,
#        11.33227858,  6.93696311, 10.8495253 ,  9.68759015,  8.51425604,
#         3.98      ,  9.41352187, 14.83545989, 12.54233041, 11.01083331,
#        10.77550184,  9.91026533, 11.10124667,  5.66293318, 11.81098622,
#        10.31943202, 10.64668057, 10.37147147,  7.77987826,  6.74292708,
#         9.40627732, 10.27852221, 12.10313237,  9.04104304,  7.53125604,
#         6.13987879,  4.        ,  6.7571645 ,  7.71347619,  9.33813276,
#        11.02788845, 10.711501  ,  9.5641313 , 10.44848235,  9.70483381,
#         7.48514493])

# %%
errors=abs(y_preds-y_test)

# %%
mape = np.mean(100 * (errors / y_test))

# %%
accuracy=100-mape

# %%
print('The best model has an accuracy of',round(accuracy,2),'%')
# Out:
# The best model has an accuracy of 84.49 %

# %%
#RMSE
grid_mse=mean_squared_error(y_test,y_preds)
rmse=np.sqrt(grid_mse)
print('The best model has a RMSE of',round(rmse,2))
# Out:
# The best model has a RMSE of 2.33
